# %%
import matplotlib.pyplot as plt
import pickle as pl
import os
import numpy as np

# %%
dir = 'saves/DUN_agw_1d_10_100_0.001_0.0001_1_10_variance/0/' #10_10dskflw/media/'

# %%
fig = pl.load(open(dir + 'val_error.pickle', 'rb'))
fig.show()

# %%
fig.axes[0].

# %%
prior_decay = 0.95
prior_probs = [(1 - prior_decay)**i for i in range(10+1)]
prior_probs = [p/sum(prior_probs) for p in prior_probs]

# %%
x = range(10+1)
plt.bar(x, prior_probs)
plt.title(f'Prior decay {prior_decay}')
plt.savefig(f'saves/prior_decay_{prior_decay}.png')
